# %% [markdown]
# ## Example usage of BasicRAG from rag-colls
#
# BasicRAG is the most simplest version of RAG for anyone to begin learning RAG.

# %% [markdown]
# ### Install libraries

# %%
# !pip install rag-colls
# Out:
# Collecting rag-colls
#   Downloading rag_colls-0.1.0-py3-none-any.whl.metadata (448 bytes)
# Collecting chromadb>=0.6.3 (from rag-colls)
#   Downloading chromadb-0.6.3-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: gdown>=5.2.0 in /usr/local/lib/python3.11/dist-packages (from rag-colls) (5.2.0)
# Collecting litellm>=1.65.0 (from rag-colls)
#   Downloading litellm-1.65.0-py3-none-any.whl.metadata (36 kB)
# Collecting llama-index-embeddings-openai>=0.3.1 (from rag-colls)
#   Downloading llama_index_embeddings_openai-0.3.1-py3-none-any.whl.metadata (684 bytes)
# Collecting loguru>=0.7.3 (from rag-colls)
#   Downloading loguru-0.7.3-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: platformdirs>=4.3.7 in /usr/local/lib/python3.11/dist-packages (from rag-colls) (4.3.7)
# Collecting pymupdf>=1.25.4 (from rag-colls)
#   Downloading pymupdf-1.25.4-cp39-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (3.4 kB)
# Requirement already satisfied: rich>=13.9.4 in /usr/local/lib/python3.11/dist-packages (from rag-colls) (13.9.4)
# Requirement already satisfied: tenacity>=9.0.0 in /usr/local/lib/python3.11/dist-packages (from rag-colls) (9.0.0)
# Collecting build>=1.0.3 (from chromadb>=0.6.3->rag-colls)
#   Downloading build-1.2.2.post1-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: pydantic>=1.9 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.6.3->rag-colls) (2.10.6)
# Collecting chroma-hnswlib==0.7.6 (from chromadb>=0.6.3->rag-colls)
#   Downloading chroma_hnswlib-0.7.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (252 bytes)
# Collecting fastapi>=0.95.2 (from chromadb>=0.6.3->rag-colls)
#   Downloading fastapi-0.115.12-py3-none-any.whl.metadata (27 kB)
# Collecting uvicorn>=0.18.3 (from uvicorn[standard]>=0.18.3->chromadb>=0.6.3->rag-colls)
#   Downloading uvicorn-0.34.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: numpy>=1.22.5 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.6.3->rag-colls) (2.0.2)
# Collecting posthog>=2.4.0 (from chromadb>=0.6.3->rag-colls)
#   Downloading posthog-3.23.0-py2.py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: typing_extensions>=4.5.0 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.6.3->rag-colls) (4.12.2)
# Collecting onnxruntime>=1.14.1 (from chromadb>=0.6.3->rag-colls)
#   Downloading onnxruntime-1.21.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (4.5 kB)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.6.3->rag-colls) (1.31.1)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0 (from chromadb>=0.6.3->rag-colls)
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.31.1-py3-none-any.whl.metadata (2.5 kB)
# Collecting opentelemetry-instrumentation-fastapi>=0.41b0 (from chromadb>=0.6.3->rag-colls)
#   Downloading opentelemetry_instrumentation_fastapi-0.52b1-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.6.3->rag-colls) (1.31.1)
# Requirement already satisfied: tokenizers>=0.13.2 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.6.3->rag-colls) (0.21.1)
# Collecting pypika>=0.48.9 (from chromadb>=0.6.3->rag-colls)
#   Downloading PyPika-0.48.9.tar.gz (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 3.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: tqdm>=4.65.0 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.6.3->rag-colls) (4.67.1)
# Collecting overrides>=7.3.1 (from chromadb>=0.6.3->rag-colls)
#   Downloading overrides-7.7.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.6.3->rag-colls) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.6.3->rag-colls) (1.71.0)
# Collecting bcrypt>=4.0.1 (from chromadb>=0.6.3->rag-colls)
#   Downloading bcrypt-4.3.0-cp39-abi3-manylinux_2_34_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: typer>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.6.3->rag-colls) (0.15.2)
# Collecting kubernetes>=28.1.0 (from chromadb>=0.6.3->rag-colls)
#   Downloading kubernetes-32.0.1-py2.py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: PyYAML>=6.0.0 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.6.3->rag-colls) (6.0.2)
# Collecting mmh3>=4.0.1 (from chromadb>=0.6.3->rag-colls)
#   Downloading mmh3-5.1.0-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (16 kB)
# Requirement already satisfied: orjson>=3.9.12 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.6.3->rag-colls) (3.10.15)
# Requirement already satisfied: httpx>=0.27.0 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.6.3->rag-colls) (0.28.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from gdown>=5.2.0->rag-colls) (4.13.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from gdown>=5.2.0->rag-colls) (3.18.0)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.11/dist-packages (from gdown>=5.2.0->rag-colls) (2.32.3)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from litellm>=1.65.0->rag-colls) (3.11.14)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from litellm>=1.65.0->rag-colls) (8.1.8)
# Requirement already satisfied: importlib-metadata>=6.8.0 in /usr/local/lib/python3.11/dist-packages (from litellm>=1.65.0->rag-colls) (8.6.1)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.2 in /usr/local/lib/python3.11/dist-packages (from litellm>=1.65.0->rag-colls) (3.1.6)
# Requirement already satisfied: jsonschema<5.0.0,>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from litellm>=1.65.0->rag-colls) (4.23.0)
# Requirement already satisfied: openai>=1.66.1 in /usr/local/lib/python3.11/dist-packages (from litellm>=1.65.0->rag-colls) (1.68.2)
# Collecting python-dotenv>=0.2.0 (from litellm>=1.65.0->rag-colls)
#   Downloading python_dotenv-1.1.0-py3-none-any.whl.metadata (24 kB)
# Collecting tiktoken>=0.7.0 (from litellm>=1.65.0->rag-colls)
#   Downloading tiktoken-0.9.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Collecting llama-index-core<0.13.0,>=0.12.0 (from llama-index-embeddings-openai>=0.3.1->rag-colls)
#   Downloading llama_index_core-0.12.27-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=13.9.4->rag-colls) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=13.9.4->rag-colls) (2.18.0)
# Requirement already satisfied: packaging>=19.1 in /usr/local/lib/python3.11/dist-packages (from build>=1.0.3->chromadb>=0.6.3->rag-colls) (24.2)
# Collecting pyproject_hooks (from build>=1.0.3->chromadb>=0.6.3->rag-colls)
#   Downloading pyproject_hooks-1.2.0-py3-none-any.whl.metadata (1.3 kB)
# Collecting starlette<0.47.0,>=0.40.0 (from fastapi>=0.95.2->chromadb>=0.6.3->rag-colls)
#   Downloading starlette-0.46.1-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx>=0.27.0->chromadb>=0.6.3->rag-colls) (4.9.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx>=0.27.0->chromadb>=0.6.3->rag-colls) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx>=0.27.0->chromadb>=0.6.3->rag-colls) (1.0.7)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/dist-packages (from httpx>=0.27.0->chromadb>=0.6.3->rag-colls) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx>=0.27.0->chromadb>=0.6.3->rag-colls) (0.14.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib-metadata>=6.8.0->litellm>=1.65.0->rag-colls) (3.21.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2<4.0.0,>=3.1.2->litellm>=1.65.0->rag-colls) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.11/dist-packages (from jsonschema<5.0.0,>=4.22.0->litellm>=1.65.0->rag-colls) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema<5.0.0,>=4.22.0->litellm>=1.65.0->rag-colls) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema<5.0.0,>=4.22.0->litellm>=1.65.0->rag-colls) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema<5.0.0,>=4.22.0->litellm>=1.65.0->rag-colls) (0.23.1)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from kubernetes>=28.1.0->chromadb>=0.6.3->rag-colls) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.11/dist-packages (from kubernetes>=28.1.0->chromadb>=0.6.3->rag-colls) (2.8.2)
# Requirement already satisfied: google-auth>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from kubernetes>=28.1.0->chromadb>=0.6.3->rag-colls) (2.38.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /usr/local/lib/python3.11/dist-packages (from kubernetes>=28.1.0->chromadb>=0.6.3->rag-colls) (1.8.0)
# Requirement already satisfied: requests-oauthlib in /usr/local/lib/python3.11/dist-packages (from kubernetes>=28.1.0->chromadb>=0.6.3->rag-colls) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in /usr/local/lib/python3.11/dist-packages (from kubernetes>=28.1.0->chromadb>=0.6.3->rag-colls) (3.2.2)
# Requirement already satisfied: urllib3>=1.24.2 in /usr/local/lib/python3.11/dist-packages (from kubernetes>=28.1.0->chromadb>=0.6.3->rag-colls) (2.3.0)
# Collecting durationpy>=0.7 (from kubernetes>=28.1.0->chromadb>=0.6.3->rag-colls)
#   Downloading durationpy-0.9-py3-none-any.whl.metadata (338 bytes)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in /usr/local/lib/python3.11/dist-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai>=0.3.1->rag-colls) (2.0.39)
# Collecting banks<3.0.0,>=2.0.0 (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai>=0.3.1->rag-colls)
#   Downloading banks-2.1.0-py3-none-any.whl.metadata (11 kB)
# Collecting dataclasses-json (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai>=0.3.1->rag-colls)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: deprecated>=1.2.9.3 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai>=0.3.1->rag-colls) (1.2.18)
# Collecting dirtyjson<2.0.0,>=1.0.8 (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai>=0.3.1->rag-colls)
#   Downloading dirtyjson-1.0.8-py3-none-any.whl.metadata (11 kB)
# Collecting filetype<2.0.0,>=1.2.0 (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai>=0.3.1->rag-colls)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai>=0.3.1->rag-colls) (2025.3.0)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai>=0.3.1->rag-colls) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai>=0.3.1->rag-colls) (3.4.2)
# Requirement already satisfied: nltk>3.8.1 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai>=0.3.1->rag-colls) (3.9.1)
# Requirement already satisfied: pillow>=9.0.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai>=0.3.1->rag-colls) (11.1.0)
# Collecting typing-inspect>=0.8.0 (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai>=0.3.1->rag-colls)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai>=0.3.1->rag-colls) (1.17.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->litellm>=1.65.0->rag-colls) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->litellm>=1.65.0->rag-colls) (1.3.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->litellm>=1.65.0->rag-colls) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->litellm>=1.65.0->rag-colls) (6.2.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->litellm>=1.65.0->rag-colls) (0.3.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->litellm>=1.65.0->rag-colls) (1.18.3)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=13.9.4->rag-colls) (0.1.2)
# Collecting coloredlogs (from onnxruntime>=1.14.1->chromadb>=0.6.3->rag-colls)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.11/dist-packages (from onnxruntime>=1.14.1->chromadb>=0.6.3->rag-colls) (25.2.10)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.11/dist-packages (from onnxruntime>=1.14.1->chromadb>=0.6.3->rag-colls) (5.29.4)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from onnxruntime>=1.14.1->chromadb>=0.6.3->rag-colls) (1.13.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from openai>=1.66.1->litellm>=1.65.0->rag-colls) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from openai>=1.66.1->litellm>=1.65.0->rag-colls) (0.9.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from openai>=1.66.1->litellm>=1.65.0->rag-colls) (1.3.1)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb>=0.6.3->rag-colls) (1.69.2)
# Collecting opentelemetry-exporter-otlp-proto-common==1.31.1 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb>=0.6.3->rag-colls)
#   Downloading opentelemetry_exporter_otlp_proto_common-1.31.1-py3-none-any.whl.metadata (1.9 kB)
# Collecting opentelemetry-proto==1.31.1 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb>=0.6.3->rag-colls)
#   Downloading opentelemetry_proto-1.31.1-py3-none-any.whl.metadata (2.4 kB)
# Collecting opentelemetry-instrumentation-asgi==0.52b1 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.6.3->rag-colls)
#   Downloading opentelemetry_instrumentation_asgi-0.52b1-py3-none-any.whl.metadata (2.1 kB)
# Collecting opentelemetry-instrumentation==0.52b1 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.6.3->rag-colls)
#   Downloading opentelemetry_instrumentation-0.52b1-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.52b1 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.6.3->rag-colls) (0.52b1)
# Collecting opentelemetry-util-http==0.52b1 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.6.3->rag-colls)
#   Downloading opentelemetry_util_http-0.52b1-py3-none-any.whl.metadata (2.6 kB)
# Collecting asgiref~=3.0 (from opentelemetry-instrumentation-asgi==0.52b1->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.6.3->rag-colls)
#   Downloading asgiref-3.8.1-py3-none-any.whl.metadata (9.3 kB)
# Collecting monotonic>=1.5 (from posthog>=2.4.0->chromadb>=0.6.3->rag-colls)
#   Downloading monotonic-1.6-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting backoff>=1.10.0 (from posthog>=2.4.0->chromadb>=0.6.3->rag-colls)
#   Downloading backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=1.9->chromadb>=0.6.3->rag-colls) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=1.9->chromadb>=0.6.3->rag-colls) (2.27.2)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.11/dist-packages (from tiktoken>=0.7.0->litellm>=1.65.0->rag-colls) (2024.11.6)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.11/dist-packages (from tokenizers>=0.13.2->chromadb>=0.6.3->rag-colls) (0.29.3)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer>=0.9.0->chromadb>=0.6.3->rag-colls) (1.5.4)
# Collecting httptools>=0.6.3 (from uvicorn[standard]>=0.18.3->chromadb>=0.6.3->rag-colls)
#   Downloading httptools-0.6.4-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.6 kB)
# Collecting uvloop!=0.15.0,!=0.15.1,>=0.14.0 (from uvicorn[standard]>=0.18.3->chromadb>=0.6.3->rag-colls)
#   Downloading uvloop-0.21.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.18.3->chromadb>=0.6.3->rag-colls)
#   Downloading watchfiles-1.0.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Requirement already satisfied: websockets>=10.4 in /usr/local/lib/python3.11/dist-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.6.3->rag-colls) (15.0.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->gdown>=5.2.0->rag-colls) (2.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown>=5.2.0->rag-colls) (3.4.1)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown>=5.2.0->rag-colls) (1.7.1)
# Collecting griffe (from banks<3.0.0,>=2.0.0->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai>=0.3.1->rag-colls)
#   Downloading griffe-1.7.1-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=0.6.3->rag-colls) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=0.6.3->rag-colls) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=0.6.3->rag-colls) (4.9)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai>=0.3.1->rag-colls) (1.4.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.11/dist-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai>=0.3.1->rag-colls) (3.1.1)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect>=0.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai>=0.3.1->rag-colls)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl.metadata (1.1 kB)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime>=1.14.1->chromadb>=0.6.3->rag-colls)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai>=0.3.1->rag-colls)
#   Downloading marshmallow-3.26.1-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->onnxruntime>=1.14.1->chromadb>=0.6.3->rag-colls) (1.3.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=0.6.3->rag-colls) (0.6.1)
# Collecting colorama>=0.4 (from griffe->banks<3.0.0,>=2.0.0->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai>=0.3.1->rag-colls)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Downloading rag_colls-0.1.0-py3-none-any.whl (23 kB)
# Downloading chromadb-0.6.3-py3-none-any.whl (611 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 611.1/611.1 kB 22.0 MB/s eta 0:00:00
# Downloading chroma_hnswlib-0.7.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 53.0 MB/s eta 0:00:00
# Downloading litellm-1.65.0-py3-none-any.whl (7.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 94.6 MB/s eta 0:00:00
# Downloading llama_index_embeddings_openai-0.3.1-py3-none-any.whl (6.2 kB)
# Downloading loguru-0.7.3-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 4.9 MB/s eta 0:00:00
# Downloading pymupdf-1.25.4-cp39-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (20.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.0/20.0 MB 80.7 MB/s eta 0:00:00
# Downloading bcrypt-4.3.0-cp39-abi3-manylinux_2_34_x86_64.whl (284 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 284.2/284.2 kB 24.0 MB/s eta 0:00:00
# Downloading build-1.2.2.post1-py3-none-any.whl (22 kB)
# Downloading fastapi-0.115.12-py3-none-any.whl (95 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.2/95.2 kB 9.3 MB/s eta 0:00:00
# Downloading kubernetes-32.0.1-py2.py3-none-any.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 68.3 MB/s eta 0:00:00
# Downloading llama_index_core-0.12.27-py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 69.2 MB/s eta 0:00:00
# Downloading mmh3-5.1.0-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (101 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.6/101.6 kB 8.4 MB/s eta 0:00:00
# Downloading onnxruntime-1.21.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.0/16.0 MB 90.2 MB/s eta 0:00:00
# Downloading opentelemetry_exporter_otlp_proto_grpc-1.31.1-py3-none-any.whl (18 kB)
# Downloading opentelemetry_exporter_otlp_proto_common-1.31.1-py3-none-any.whl (18 kB)
# Downloading opentelemetry_proto-1.31.1-py3-none-any.whl (55 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.9/55.9 kB 4.8 MB/s eta 0:00:00
# Downloading opentelemetry_instrumentation_fastapi-0.52b1-py3-none-any.whl (12 kB)
# Downloading opentelemetry_instrumentation-0.52b1-py3-none-any.whl (31 kB)
# Downloading opentelemetry_instrumentation_asgi-0.52b1-py3-none-any.whl (16 kB)
# Downloading opentelemetry_util_http-0.52b1-py3-none-any.whl (7.3 kB)
# Downloading overrides-7.7.0-py3-none-any.whl (17 kB)
# Downloading posthog-3.23.0-py2.py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.0/85.0 kB 8.1 MB/s eta 0:00:00
# Downloading python_dotenv-1.1.0-py3-none-any.whl (20 kB)
# Downloading tiktoken-0.9.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 58.4 MB/s eta 0:00:00
# Downloading uvicorn-0.34.0-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.3/62.3 kB 5.9 MB/s eta 0:00:00
# Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Downloading banks-2.1.0-py3-none-any.whl (28 kB)
# Downloading dirtyjson-1.0.8-py3-none-any.whl (25 kB)
# Downloading durationpy-0.9-py3-none-any.whl (3.5 kB)
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading httptools-0.6.4-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (459 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 459.8/459.8 kB 27.8 MB/s eta 0:00:00
# Downloading monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Downloading starlette-0.46.1-py3-none-any.whl (71 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 6.3 MB/s eta 0:00:00
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading uvloop-0.21.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 92.2 MB/s eta 0:00:00
# Downloading watchfiles-1.0.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (452 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 452.6/452.6 kB 31.7 MB/s eta 0:00:00
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 3.6 MB/s eta 0:00:00
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading pyproject_hooks-1.2.0-py3-none-any.whl (10 kB)
# Downloading asgiref-3.8.1-py3-none-any.whl (23 kB)
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 7.3 MB/s eta 0:00:00
# Downloading marshmallow-3.26.1-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 4.0 MB/s eta 0:00:00
# Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Downloading griffe-1.7.1-py3-none-any.whl (129 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.1/129.1 kB 11.3 MB/s eta 0:00:00
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Building wheels for collected packages: pypika
#   Building wheel for pypika (pyproject.toml) ... done
#   Created wheel for pypika: filename=pypika-0.48.9-py2.py3-none-any.whl size=53800 sha256=623e2a4b2767fd2530db7f66d68196de12546440b8f706f252c06cc7e53a2271
#   Stored in directory: /root/.cache/pip/wheels/a3/01/bd/4c40ceb9d5354160cb186dcc153360f4ab7eb23e2b24daf96d
# Successfully built pypika
# Installing collected packages: pypika, monotonic, filetype, durationpy, dirtyjson, uvloop, uvicorn, python-dotenv, pyproject_hooks, pymupdf, overrides, opentelemetry-util-http, opentelemetry-proto, mypy-extensions, mmh3, marshmallow, loguru, humanfriendly, httptools, colorama, chroma-hnswlib, bcrypt, backoff, asgiref, watchfiles, typing-inspect, tiktoken, starlette, posthog, opentelemetry-exporter-otlp-proto-common, griffe, coloredlogs, build, onnxruntime, kubernetes, fastapi, dataclasses-json, banks, opentelemetry-instrumentation, llama-index-core, litellm, opentelemetry-instrumentation-asgi, opentelemetry-exporter-otlp-proto-grpc, llama-index-embeddings-openai, opentelemetry-instrumentation-fastapi, chromadb, rag-colls
# Successfully installed asgiref-3.8.1 backoff-2.2.1 banks-2.1.0 bcrypt-4.3.0 build-1.2.2.post1 chroma-hnswlib-0.7.6 chromadb-0.6.3 colorama-0.4.6 coloredlogs-15.0.1 dataclasses-json-0.6.7 dirtyjson-1.0.8 durationpy-0.9 fastapi-0.115.12 filetype-1.2.0 griffe-1.7.1 httptools-0.6.4 humanfriendly-10.0 kubernetes-32.0.1 litellm-1.65.0 llama-index-core-0.12.27 llama-index-embeddings-openai-0.3.1 loguru-0.7.3 marshmallow-3.26.1 mmh3-5.1.0 monotonic-1.6 mypy-extensions-1.0.0 onnxruntime-1.21.0 opentelemetry-exporter-otlp-proto-common-1.31.1 opentelemetry-exporter-otlp-proto-grpc-1.31.1 opentelemetry-instrumentation-0.52b1 opentelemetry-instrumentation-asgi-0.52b1 opentelemetry-instrumentation-fastapi-0.52b1 opentelemetry-proto-1.31.1 opentelemetry-util-http-0.52b1 overrides-7.7.0 posthog-3.23.0 pymupdf-1.25.4 pypika-0.48.9 pyproject_hooks-1.2.0 python-dotenv-1.1.0 rag-colls-0.1.0 starlette-0.46.1 tiktoken-0.9.0 typing-inspect-0.9.0 uvicorn-0.34.0 uvloop-0.21.0 watchfiles-1.0.4

# %% [markdown]
# ### Download sample data (some papers)

# %%
# !gdown --fuzzy https://drive.google.com/file/d/1Hl5EU4WzQ7C9-NAEZlliYjkMdHnDOWWl/view?usp=sharing

# !unzip papers.zip -d samples

# !rm papers.zip
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1Hl5EU4WzQ7C9-NAEZlliYjkMdHnDOWWl
# To: /content/papers.zip
# 100% 21.7M/21.7M [00:00<00:00, 36.4MB/s]
# Archive:  papers.zip
#   inflating: samples/papers/2308.11432v5.pdf
#   inflating: samples/papers/2312.00752v2.pdf
#   inflating: samples/papers/2312.10997v5.pdf
#   inflating: samples/papers/2409.13571v1.pdf
#   inflating: samples/papers/2409.13576v1.pdf
#   inflating: samples/papers/2409.13588v1.pdf
#   inflating: samples/papers/Li_Density_Map_Guided_Object_Detection_in_Aerial_Images_CVPRW_2020_paper.pdf

# %% [markdown]
# ### Prepare OPEN_AI_API key

# %%
# In this example, we will use openai models.
import os
from google.colab import userdata

os.environ["OPENAI_API_KEY"] = userdata.get("OPENAI_API_KEY")

# If you run on your local machine, uncomment, fill your api key here and run this
# os.environ['OPENAI_API_KEY'] = "YOUR_OPENAI_API_KEY"

# %% [markdown]
# ### Import core components of rag-colls

# %%
from rag_colls.rags.basic_rag import BasicRAG
from rag_colls.llms.litellm_llm import LiteLLM
from rag_colls.embeddings.openai_embedding import OpenAIEmbedding
from rag_colls.processors.chunkers.semantic_chunker import SemanticChunker
from rag_colls.databases.vector_databases.chromadb import ChromaVectorDatabase

# %% [markdown]
# ### Initialize BasicRAG

# %%
rag = BasicRAG(
    vector_database=ChromaVectorDatabase(
        persistent_directory="./chroma_db", collection_name="test"
    ),
    chunker=SemanticChunker(embed_model_name="text-embedding-ada-002"),
    llm=LiteLLM(model_name="openai/gpt-4o-mini"),
    embed_model=OpenAIEmbedding(model_name="text-embedding-ada-002"),
)
# Out:
# 2025-03-30 15:53:45.828 | SUCCESS  | rag_colls.loggers.loguru:success:70 - ChromaVectorDatabase initialized successfully !!!
# 2025-03-30 15:53:45.882 | SUCCESS  | rag_colls.loggers.loguru:success:70 - Collection test created successfully !!!
# 2025-03-30 15:53:45.884 | INFO     | rag_colls.loggers.loguru:info:26 - No processors provided. Using default processors ...
# 2025-03-30 15:53:45.885 | INFO     | rag_colls.loggers.loguru:info:26 - Initializing default file processors ...

# %% [markdown]
# ### Run ingest in a single file
#
# You could run more files but in this example, we only run once.

# %%
rag.ingest_db(file_paths=["samples/papers/2409.13588v1.pdf"], batch_embedding=100)
# Out:
# 2025-03-30 15:54:32.182 | INFO     | rag_colls.loggers.loguru:info:26 - Processing 1 files ...
# 2025-03-30 15:54:33.210 | INFO     | rag_colls.loggers.loguru:info:26 - Get 12 documents.
# Parsing nodes:   0%|          | 0/12 [00:00<?, ?it/s]
# Generating embeddings:   0%|          | 0/22 [00:00<?, ?it/s]
# Generating embeddings:   0%|          | 0/37 [00:00<?, ?it/s]
# Generating embeddings:   0%|          | 0/44 [00:00<?, ?it/s]
# Generating embeddings:   0%|          | 0/28 [00:00<?, ?it/s]
# Generating embeddings:   0%|          | 0/33 [00:00<?, ?it/s]
# Generating embeddings:   0%|          | 0/41 [00:00<?, ?it/s]
# Generating embeddings:   0%|          | 0/24 [00:00<?, ?it/s]
# Generating embeddings:   0%|          | 0/52 [00:00<?, ?it/s]
# Generating embeddings:   0%|          | 0/49 [00:00<?, ?it/s]
# Generating embeddings:   0%|          | 0/44 [00:00<?, ?it/s]
# Generating embeddings:   0%|          | 0/191 [00:00<?, ?it/s]
# Generating embeddings:   0%|          | 0/43 [00:00<?, ?it/s]
# Embedding ...: 100%|██████████| 1/1 [00:00<00:00,  1.19it/s]
# 2025-03-30 15:54:50.055 | SUCCESS  | rag_colls.loggers.loguru:success:70 - Added: 48 documents.

# %% [markdown]
# ### Perform search

# %%
response, usage = rag.search(query="Chain Buddy là gì ?", top_k=5)

print(response)
print("===========")
print(usage)
# Out:
# ChainBuddy là một hệ thống AI trợ lý được thiết kế để tự động hóa việc tạo ra các pipel (đường ống) cho các mô hình ngôn ngữ lớn (LLM). Nó hoạt động trong nền tảng open-source ChainForge và cung cấp một giao diện người dùng thân thiện, tương tác giống như chatbot, giúp người dùng dễ dàng lập kế hoạch và đánh giá hành vi của các LLM. ChainBuddy nhằm giải quyết vấn đề khó khăn mà người dùng thường gặp khi bắt đầu từ con số không (vấn đề trang trắng) và hỗ trợ họ trong quá trình sản xuất các pipel cho nhiều tác vụ khác nhau, như xử lý dữ liệu và tối ưu hóa lời nhắc (prompt).
# ===========
# LLMUsage(prompt_tokens=1495, completion_tokens=150, total_tokens=1645)
